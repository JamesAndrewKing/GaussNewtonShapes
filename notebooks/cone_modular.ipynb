# %% [markdown]
# # Zero Gaussian Curvature Cone Section
#
# ### Imports and setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import optim
from tqdm.notebook import trange
import k3d
import sys
import os
import time
import copy
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from models.model_architecture import GeneralNet
from training.optimizers import GaussNewton
from util.surface_sampling import sample_model_surface_binsearch, sample_model_surface_newton 
from util.error_metrics import chamfer_div, compute_distance 
from util.visualization.utils_mesh import get_mesh
from training.modular.residuals import ResidualLibrary, ResidualTerm, compute_loss
from training.modular.optimizers import GaussNewton


torch.manual_seed(0)


device = 'cpu' #if torch.cuda.is_available() else 'cpu'
torch.set_default_device(device)

# %% [markdown]
# ### True Surface

# %%
def sample_boundary(n_points=1200, dtype=torch.float64):
    third = n_points // 3
    t = torch.linspace(0, 2 * torch.pi, third, dtype=dtype)

    z1 = -torch.zeros_like(t)
    y1 = 1.0 * torch.cos(t)
    x1 = 1.0 * torch.sin(t)

    # Left loop in y-z plane (like helicoid end)
    z2 = torch.ones_like(t)
    y2 = 0.4 * torch.cos(t)
    x2 = 0.4 * torch.sin(t)

    loop1 = torch.vstack([x1, y1, z1])
    loop2 = torch.vstack([x2, y2, z2])
    return torch.cat([loop1, loop2], dim=1).T

pts_boundary = sample_boundary(n_points=1000)

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.points(pts_boundary.cpu().detach(), color=0x00ff00, point_size=0.05)

fig.display()
# Out:
# Output()

# %% [markdown]
# ### Pretraining

# %%
model = GeneralNet(ks=[3, 32, 32, 1])
model = model.double()
torch.compile(model)
# bind_model(model)
# Generate random training points
num_pretrain_samples = 10000
bounds = torch.tensor([[-1,1], [-1,1], [-1,1]], dtype=torch.float64)
pts_pretrain = torch.rand(num_pretrain_samples, 3, dtype=torch.float64) * (bounds[:,1] - bounds[:,0]) + bounds[:,0]


def pretrain_loss(model, params, pts):
    inputs = pts.to(dtype=torch.float64)
    x, y = pts[:, 0], pts[:, 1]
    targets = x**2 + y**2 - 1
    preds = model(inputs).squeeze(1)
    return 0.5 * (preds - targets).square().mean()

# Pretraining loop
pretrain_optimizer = optim.Adam(model.parameters(), lr=1e-3)
num_pretrain_iters = 1000

for i in range(num_pretrain_iters):
    pretrain_optimizer.zero_grad()
    loss = pretrain_loss(model, model.params, pts_pretrain)
    loss.backward()
    pretrain_optimizer.step()
    
    if i % 100 == 0:
        print(f"Pretrain Iter {i}: Loss= {loss.item():.6f}")

print("Pretraining completed!")

verts, faces = get_mesh(
    model.float(), N=128, device=device,
    bbox_min=torch.tensor([-3, -3, -1.5], dtype=torch.float64),
    bbox_max=torch.tensor([3, 3, 1.5], dtype=torch.float64),
    chunks=2
)

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(verts, faces, color=0xbbbbbb, side='double', flat_shading=False)
fig += k3d.points(pts_boundary.cpu().detach(), color=0x00ff00, point_size=0.05)
fig.display()
# Out:
# Pretrain Iter 0: Loss= 0.119938
# Pretrain Iter 100: Loss= 0.072818
# Pretrain Iter 200: Loss= 0.010990
# Pretrain Iter 300: Loss= 0.002189
# Pretrain Iter 400: Loss= 0.000861
# Pretrain Iter 500: Loss= 0.000384
# Pretrain Iter 600: Loss= 0.000202
# Pretrain Iter 700: Loss= 0.000131
# Pretrain Iter 800: Loss= 0.000099
# Pretrain Iter 900: Loss= 0.000082
# Pretraining completed!
# /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/traittypes/traittypes.py:97: UserWarning: Given trait value dtype "int32" does not match required type "uint32". A coerced copy has been created.
#   warnings.warn(
# Output()

# %% [markdown]
# ### Main training loop

# %%
res_lib = ResidualLibrary(model)

pts_eikonal = 2 * torch.rand([1000, 3], dtype=torch.float64) - 1
pts_eikonal = torch.cat((pts_eikonal, pts_boundary))

## Select the residual terms defining the specific problem
## (incl. weight, points, and (optional) target values)
res_terms = {
    "data":
        ResidualTerm(res_lib._data,           1.0,  pts_boundary, vals=0),
    "eikonal":
        ResidualTerm(res_lib._eikonal,        1e-3, pts_eikonal,        ),
    "gauss_curvature":
        ResidualTerm(res_lib._gauss_curvature, 1.0,  pts_boundary,       ),
}

# %%
model = model.double()
params = model.params
loss_over_time = {}
best_loss = float('inf')

optim = GaussNewton(model, res_terms, lr=1e-1, regularization=1e-6, do_line_search=False)
# optim = torch.optim.Adam(model.parameters(), lr=1e-3)
start_time = time.time()
current_time = 0

for i in (pbar:=trange(100000)):
    # if current_time > 1200:
    if current_time > 600: # Shorter run for testing
        break
    optim.zero_grad()
    ## Update weights
    if i == 500:
        loss_weights = {"data": 1.0, "eikonal": 0.0, "gauss_curvature": 1.0}
        for key in res_terms:
            res_terms[key].weight = loss_weights[key]

    ## Update surface points
    bound_limit = 1.0
    bounds = torch.tensor([[-bound_limit,bound_limit], [-bound_limit,bound_limit], [-bound_limit,bound_limit]], dtype=torch.float64)
    pts_surface = sample_model_surface_binsearch(model, pts_boundary, bounds)
    res_terms["gauss_curvature"].points = pts_surface
    
    ## Evaluate the losses
    loss, unweighted_losses = compute_loss(params, res_terms, return_unweighted_losses=True)
        
    loss.backward()
    
    with torch.no_grad():
        loss_metric = unweighted_losses["data"] + unweighted_losses["gauss_curvature"]

        current_time = time.time() - start_time
        loss_over_time[current_time] = loss_metric.item()
        if loss_metric.item() < best_loss:
            best_loss = loss_metric.item()
            best_model_state = copy.deepcopy(model.state_dict())

        unweighted_losses_str = " ".join(f"{key}: {l.item():.2e}" for key, l in unweighted_losses.items())
        pbar.set_description(unweighted_losses_str + " "
                            f"nof_pts: {len(pts_surface)}"
                            )
    optim.step()

# Optional: Load the best model after training
# if best_model_state is not None:
#     model.load_state_dict(best_model_state)
#     print(f"Best model loaded with loss {best_loss}")

plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/miniforge3/conda-bld/libtorch_1741947704867/work/aten/src/ATen/native/TensorShape.cpp:3638.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 46
#      42         unweighted_losses_str = " ".join(f"{key}: {l.item():.2e}" for key, l in unweighted_losses.items())
#      43         pbar.set_description(unweighted_losses_str + " "
#      44                             f"nof_pts: {len(pts_surface)}"
#      45                             )
# ---> 46     optim.step()
#      48 # Optional: Load the best model after training
#      49 # if best_model_state is not None:
#      50 #     model.load_state_dict(best_model_state)
#      51 #     print(f"Best model loaded with loss {best_loss}")
#      53 plt.plot(loss_over_time.keys(), loss_over_time.values())
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/PreconditionGINNs/training/modular/optimizers.py:52, in GaussNewton.step(self)
#      47 """
#      48 Perform a single Gauss-Newton update step on all parameters:
#      49 """
#      50 self.t += 1
# ---> 52 self.apply_preconditioner_to_grads()
#      54 # if not self.do_line_search:
#      55 #     for param in self.params_list:
#      56 #         if param.grad is None:
#      57 #             continue
#      58 #         param.data -= self.lr * param.grad
#      59 # If line search is enabled
#      60 if self.do_line_search:
#
# File ~/PreconditionGINNs/training/modular/optimizers.py:35, in GaussNewton.apply_preconditioner_to_grads(self)
#      33 N = flat_grads.numel()
#      34 eps = self.regularization
# ---> 35 A = compute_JTJ(self.params_dict, self.res_terms) + eps*torch.eye(N)
#      37 # 2. Solve least squares: x = argmin_x ||A*x - grads||^2
#      38 x, _, _, _ = torch.linalg.lstsq(A.double(), flat_grads.double(), driver="gels")
#
# File ~/PreconditionGINNs/training/modular/gram_factory.py:14, in compute_JTJ(params, res_terms)
#      12 """Returns a tensor of shape [P,P] where P is the number of parameters"""
#      13 ## skip a residual term if it has no points, since these are sometimes found dynamically
# ---> 14 JTJ = sum(
#      15     res_term.weight * compute_JTJ_per_residual(params, res_term)
#      16     for res_term in res_terms.values() if len(res_term.points)>0
#      17 )
#      18 return JTJ
#
# File ~/PreconditionGINNs/training/modular/gram_factory.py:15, in <genexpr>(.0)
#      12 """Returns a tensor of shape [P,P] where P is the number of parameters"""
#      13 ## skip a residual term if it has no points, since these are sometimes found dynamically
#      14 JTJ = sum(
# ---> 15     res_term.weight * compute_JTJ_per_residual(params, res_term)
#      16     for res_term in res_terms.values() if len(res_term.points)>0
#      17 )
#      18 return JTJ
#
# File ~/PreconditionGINNs/training/modular/gram_factory.py:6, in compute_JTJ_per_residual(params, res_term)
#       4 def compute_JTJ_per_residual(params, res_term) -> torch.Tensor:
#       5     """Returns a tensor of shape [P,P] where P is the number of parameters"""
# ----> 6     J_dict = res_term.grad_theta_r(params)
#       7     J = torch.cat([p.flatten(start_dim=1) for p in J_dict.values()], dim=1)
#       8     JTJ = torch.einsum('bi,bj->ij', J, J) / len(res_term.points)
#
# File ~/PreconditionGINNs/training/modular/residuals.py:193, in ResidualTerm.grad_theta_r(self, params)
#     187 """
#     188 Evaluate the Jacobian of the residual on the batch of self.points using vmap.
#     189 Returns:
#     190     dict of Jacobian tensors, for each param tensor the shape is: [B, 1, *param.shape]
#     191 """
#     192 _grad_theta_r = jacrev(self.func, argnums=0)
# --> 193 return self.vmap(_grad_theta_r)(params, self.points, self.vals)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/apis.py:203, in vmap.<locals>.wrapped(*args, **kwargs)
#     202 def wrapped(*args, **kwargs):
# --> 203     return vmap_impl(
#     204         func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     205     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:331, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     320     return _chunked_vmap(
#     321         func,
#     322         flat_in_dims,
#    (...)    327         **kwargs,
#     328     )
#     330 # If chunk_size is not specified.
# --> 331 return _flat_vmap(
#     332     func,
#     333     batch_size,
#     334     flat_in_dims,
#     335     flat_args,
#     336     args_spec,
#     337     out_dims,
#     338     randomness,
#     339     **kwargs,
#     340 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:479, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     475 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     476     batched_inputs = _create_batched_inputs(
#     477         flat_in_dims, flat_args, vmap_level, args_spec
#     478     )
# --> 479     batched_outputs = func(*batched_inputs, **kwargs)
#     480     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:689, in jacrev.<locals>.wrapper_fn(*args)
#     687     flat_jacobians_per_input = compute_jacobian_preallocate_and_copy()
#     688 else:
# --> 689     flat_jacobians_per_input = compute_jacobian_stacked()
#     691 # Step 2: The returned jacobian is one big tensor per input. In this step,
#     692 # we split each Tensor by output.
#     693 flat_jacobians_per_input = [
#     694     result.split(flat_output_numels, dim=0)
#     695     for result in flat_jacobians_per_input
#     696 ]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:611, in jacrev.<locals>.wrapper_fn.<locals>.compute_jacobian_stacked()
#     609     chunked_result = vjp_fn(basis)
#     610 else:  # chunk_size is None or chunk_size != 1
# --> 611     chunked_result = vmap(vjp_fn)(basis)
#     613 flat_results = pytree.tree_leaves(chunked_result)
#     615 if chunk_size == 1:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/apis.py:203, in vmap.<locals>.wrapped(*args, **kwargs)
#     202 def wrapped(*args, **kwargs):
# --> 203     return vmap_impl(
#     204         func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     205     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:331, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     320     return _chunked_vmap(
#     321         func,
#     322         flat_in_dims,
#    (...)    327         **kwargs,
#     328     )
#     330 # If chunk_size is not specified.
# --> 331 return _flat_vmap(
#     332     func,
#     333     batch_size,
#     334     flat_in_dims,
#     335     flat_args,
#     336     args_spec,
#     337     out_dims,
#     338     randomness,
#     339     **kwargs,
#     340 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:479, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     475 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     476     batched_inputs = _create_batched_inputs(
#     477         flat_in_dims, flat_args, vmap_level, args_spec
#     478     )
# --> 479     batched_outputs = func(*batched_inputs, **kwargs)
#     480     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:394, in _vjp_with_argnums.<locals>.wrapper(cotangents, retain_graph, create_graph)
#     387 if primals_out_spec != cotangents_spec:
#     388     raise RuntimeError(
#     389         f"Expected pytree structure of cotangents to be the same "
#     390         f"as pytree structure of outputs to the function. "
#     391         f"cotangents: {treespec_pprint(cotangents_spec)}, "
#     392         f"primal output: {treespec_pprint(primals_out_spec)}"
#     393     )
# --> 394 result = _autograd_grad(
#     395     flat_primals_out,
#     396     flat_diff_primals,
#     397     flat_cotangents,
#     398     retain_graph=retain_graph,
#     399     create_graph=create_graph,
#     400 )
#     401 return tree_unflatten(result, primals_spec)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:141, in _autograd_grad(outputs, inputs, grad_outputs, retain_graph, create_graph)
#     139 if len(diff_outputs) == 0:
#     140     return tuple(torch.zeros_like(inp) for inp in inputs)
# --> 141 grad_inputs = torch.autograd.grad(
#     142     diff_outputs,
#     143     inputs,
#     144     grad_outputs,
#     145     retain_graph=retain_graph,
#     146     create_graph=create_graph,
#     147     allow_unused=True,
#     148 )
#     149 grad_inputs = tuple(
#     150     torch.zeros_like(inp) if gi is None else gi
#     151     for gi, inp in zip(grad_inputs, inputs)
#     152 )
#     153 return grad_inputs
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/autograd/__init__.py:445, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     443 overridable_args = t_outputs + t_inputs
#     444 if has_torch_function(overridable_args):
# --> 445     return handle_torch_function(
#     446         grad,
#     447         overridable_args,
#     448         outputs,
#     449         inputs,
#     450         grad_outputs=grad_outputs,
#     451         retain_graph=retain_graph,
#     452         create_graph=create_graph,
#     453         only_inputs=only_inputs,
#     454         allow_unused=allow_unused,
#     455         is_grads_batched=is_grads_batched,
#     456         materialize_grads=materialize_grads,
#     457     )
#     459 if not only_inputs:
#     460     warnings.warn(
#     461         "only_inputs argument is deprecated and is ignored now "
#     462         "(defaults to True). To accumulate gradient for other "
#    (...)    465         stacklevel=2,
#     466     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/overrides.py:1720, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1716 if _is_torch_function_mode_enabled():
#    1717     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1718     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1719     with _pop_mode_temporarily() as mode:
# -> 1720         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1721     if result is not NotImplemented:
#    1722         return result
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/utils/_device.py:104, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     102 if func in _device_constructors() and kwargs.get('device') is None:
#     103     kwargs['device'] = self.device
# --> 104 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/autograd/__init__.py:496, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     492     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     493         grad_outputs_
#     494     )
#     495 else:
# --> 496     result = _engine_run_backward(
#     497         outputs,
#     498         grad_outputs_,
#     499         retain_graph,
#     500         create_graph,
#     501         inputs,
#     502         allow_unused,
#     503         accumulate_grad=False,
#     504     )
#     505 if materialize_grads:
#     506     if any(
#     507         result[i] is None and not is_tensor_like(inputs[i])
#     508         for i in range(len(inputs))
#     509     ):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_prims_common/wrappers.py:270, in out_wrapper.<locals>._out_wrapper.<locals>._fn(out, *args, **kwargs)
#     267 factory_kwargs = ("device", "dtype")
#     268 is_factory_fn = all(p in sig.parameters for p in factory_kwargs)
# --> 270 @wraps(fn)
#     271 def _fn(*args: _P.args, out=None, **kwargs: _P.kwargs):
#     272     if is_factory_fn and out is not None:
#     273         for k in factory_kwargs:
#
# KeyboardInterrupt:

# %%
model = model.double()
params = model.params
loss_over_time = {}

optim = torch.optim.LBFGS(model.parameters(), lr=1e-1, max_iter=20, history_size=10)
start_time = time.time()
current_time = 0
best_loss = float('inf')
best_model_state = None

pbar = trange(100000)
for i in pbar:
    if current_time > 600:
        break

    # Update weights
    if i == 500:
        loss_weights = {"data": 1.0, "eikonal": 0.0, "gauss_curvature": 1.0}
        for key in res_terms:
            res_terms[key].weight = loss_weights[key]

    # Update surface points
    bound_limit = 1.0
    bounds = torch.tensor([[-bound_limit, bound_limit], [-bound_limit, bound_limit], [-bound_limit, bound_limit]], dtype=torch.float64)
    pts_surface = sample_model_surface_binsearch(model, pts_boundary, bounds)
    res_terms["gauss_curvature"].points = pts_surface

    def closure():
        optim.zero_grad()
        loss, _ = compute_loss(params, res_terms, return_unweighted_losses=True)
        loss.backward()
        return loss

    loss, unweighted_losses = compute_loss(params, res_terms, return_unweighted_losses=True)
    optim.step(closure)

    with torch.no_grad():
        loss_metric = unweighted_losses["data"] + unweighted_losses["gauss_curvature"]
        current_time = time.time() - start_time
        loss_over_time[current_time] = loss_metric.item()

        if loss_metric.item() < best_loss:
            best_loss = loss_metric.item()
            best_model_state = copy.deepcopy(model.state_dict())

        unweighted_losses_str = " ".join(f"{key}: {l.item():.2e}" for key, l in unweighted_losses.items())
        pbar.set_description(unweighted_losses_str + " "
                            f"nof_pts: {len(pts_surface)}"
                            )

# Optional: Load the best model after training
# if best_model_state is not None:
#     model.load_state_dict(best_model_state)
#     print(f"Best model loaded with loss {best_loss}")

plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 36
#      33     loss.backward()
#      34     return loss
# ---> 36 loss, unweighted_losses = compute_loss(params, res_terms, return_unweighted_losses=True)
#      37 optim.step(closure)
#      39 with torch.no_grad():
#
# File ~/PreconditionGINNs/training/modular/residuals.py:198, in compute_loss(params, res_terms, return_unweighted_losses)
#     196 def compute_loss(params, res_terms, return_unweighted_losses=False):
#     197     ## skip a residual term if it has no points, since these are sometimes found dynamically
# --> 198     unweighted_losses = {key: res_term.unweighted_loss(params) for key, res_term in res_terms.items() if len(res_term.points)>0}
#     199     loss = sum(res_terms[key].weight*unweighted_losses[key] for key in unweighted_losses)
#     200     ## unweighted losses might be used for logging
#
# File ~/PreconditionGINNs/training/modular/residuals.py:177, in ResidualTerm.unweighted_loss(self, params)
#     171 def unweighted_loss(self, params) -> torch.Tensor:
#     172     r"""
#     173     Evaluate the residual 0.5 * \int r(x)^2 dx
#     174     Returns:
#     175         Scalar tensor of shape []
#     176     """
# --> 177     return 0.5*self.eval(params).square().mean()
#
# File ~/PreconditionGINNs/training/modular/residuals.py:169, in ResidualTerm.eval(self, params)
#     163 def eval(self, params) -> torch.Tensor:
#     164     """
#     165     Evaluate the model on the batch of self.points using vmap.
#     166     Returns:
#     167         Tensor of shape [B, 1]: one residual value per point
#     168     """
# --> 169     return self.vmap(self.func)(params, self.points, self.vals)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/apis.py:203, in vmap.<locals>.wrapped(*args, **kwargs)
#     202 def wrapped(*args, **kwargs):
# --> 203     return vmap_impl(
#     204         func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     205     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:331, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     320     return _chunked_vmap(
#     321         func,
#     322         flat_in_dims,
#    (...)    327         **kwargs,
#     328     )
#     330 # If chunk_size is not specified.
# --> 331 return _flat_vmap(
#     332     func,
#     333     batch_size,
#     334     flat_in_dims,
#     335     flat_args,
#     336     args_spec,
#     337     out_dims,
#     338     randomness,
#     339     **kwargs,
#     340 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:479, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     475 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     476     batched_inputs = _create_batched_inputs(
#     477         flat_in_dims, flat_args, vmap_level, args_spec
#     478     )
# --> 479     batched_outputs = func(*batched_inputs, **kwargs)
#     480     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/PreconditionGINNs/training/modular/residuals.py:103, in ResidualLibrary._gauss_curvature(self, params, x, val)
#     101 def _gauss_curvature(self, params, x, val=None):
#     102     g = self._grad_x_f(params, x).squeeze(1)
# --> 103     h = self._hess_x_f(params, x).squeeze(1)
#     104     return _gauss_curv(g, h)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:1273, in jacfwd.<locals>.wrapper_fn(*args)
#    1270     _, jvp_out = output
#    1271     return jvp_out
# -> 1273 results = vmap(push_jvp, randomness=randomness)(basis)
#    1274 if has_aux:
#    1275     results, aux = results
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/apis.py:203, in vmap.<locals>.wrapped(*args, **kwargs)
#     202 def wrapped(*args, **kwargs):
# --> 203     return vmap_impl(
#     204         func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs
#     205     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:331, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     320     return _chunked_vmap(
#     321         func,
#     322         flat_in_dims,
#    (...)    327         **kwargs,
#     328     )
#     330 # If chunk_size is not specified.
# --> 331 return _flat_vmap(
#     332     func,
#     333     batch_size,
#     334     flat_in_dims,
#     335     flat_args,
#     336     args_spec,
#     337     out_dims,
#     338     randomness,
#     339     **kwargs,
#     340 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:479, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     475 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     476     batched_inputs = _create_batched_inputs(
#     477         flat_in_dims, flat_args, vmap_level, args_spec
#     478     )
# --> 479     batched_outputs = func(*batched_inputs, **kwargs)
#     480     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:1262, in jacfwd.<locals>.wrapper_fn.<locals>.push_jvp(basis)
#    1261 def push_jvp(basis):
# -> 1262     output = _jvp_with_argnums(
#    1263         func, args, basis, argnums=argnums, has_aux=has_aux
#    1264     )
#    1265     # output[0] is the output of `func(*args)`
#    1266     error_if_complex("jacfwd", output[0], is_input=False)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:1101, in _jvp_with_argnums(func, primals, tangents, argnums, strict, has_aux)
#    1099     primals = _wrap_all_tensors(primals, level)
#    1100     duals = _replace_args(primals, duals, argnums)
# -> 1101 result_duals = func(*duals)
#    1102 if has_aux:
#    1103     if not (isinstance(result_duals, tuple) and len(result_duals) == 2):
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:569, in jacrev.<locals>.wrapper_fn(*args)
#     566 @wraps(func)
#     567 def wrapper_fn(*args):
#     568     error_if_complex("jacrev", args, is_input=True)
# --> 569     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     570     if has_aux:
#     571         output, vjp_fn, aux = vjp_out
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/vmap.py:48, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      45 @functools.wraps(f)
#      46 def fn(*args, **kwargs):
#      47     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 48         return f(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/eager_transforms.py:357, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     355     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     356     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 357 primals_out = func(*primals)
#     359 if has_aux:
#     360     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# File ~/PreconditionGINNs/training/modular/residuals.py:70, in ResidualLibrary.__init__.<locals>.<lambda>(params, x)
#      64 self.model = model
#      66 ## all of the below have the signature
#      67 ## self.*(params, x) with x being [1, D] for self._func and [B, D] for self.func
#      68
#      69 ## Single
# ---> 70 self._f        = lambda params, x: functional_call(self.model, params, x.unsqueeze(0)).squeeze(0)
#      71 self._grad_x_f = jacrev(self._f, argnums=1)
#      72 self._grad_x_f_batch = vmap(self._grad_x_f, in_dims=(None, 0))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_functorch/functional_call.py:148, in functional_call(module, parameter_and_buffer_dicts, args, kwargs, tie_weights, strict)
#     142 else:
#     143     raise ValueError(
#     144         f"Expected parameter_and_buffer_dicts to be a dict, or a list/tuple of dicts, "
#     145         f"but got {type(parameter_and_buffer_dicts)}"
#     146     )
# --> 148 return nn.utils.stateless._functional_call(
#     149     module,
#     150     parameters_and_buffers,
#     151     args,
#     152     kwargs,
#     153     tie_weights=tie_weights,
#     154     strict=strict,
#     155 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/nn/utils/stateless.py:300, in _functional_call(module, parameters_and_buffers, args, kwargs, tie_weights, strict)
#     296     args = (args,)
#     297 with _reparametrize_module(
#     298     module, parameters_and_buffers, tie_weights=tie_weights, strict=strict
#     299 ):
# --> 300     return module(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/PreconditionGINNs/models/model_architecture.py:37, in GeneralNet.forward(self, x, z)
#      35 x = self.fcs[0](x)
#      36 for i in range(2, self.D + 1):
# ---> 37     x = self.fcs[i - 1](self.act(x))
#      38 return x
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/utils/_device.py:104, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     102 if func in _device_constructors() and kwargs.get('device') is None:
#     103     kwargs['device'] = self.device
# --> 104 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ginns/lib/python3.12/site-packages/torch/_prims_common/wrappers.py:270, in out_wrapper.<locals>._out_wrapper.<locals>._fn(out, *args, **kwargs)
#     267 factory_kwargs = ("device", "dtype")
#     268 is_factory_fn = all(p in sig.parameters for p in factory_kwargs)
# --> 270 @wraps(fn)
#     271 def _fn(*args: _P.args, out=None, **kwargs: _P.kwargs):
#     272     if is_factory_fn and out is not None:
#     273         for k in factory_kwargs:
#
# KeyboardInterrupt:

# %%
# # Optional: Load the best model after training
# if best_model_state is not None:
#     model.load_state_dict(best_model_state)
#     print(f"Best model loaded with loss {best_loss}")

# %%
# torch.save(model.state_dict(), '3,32,32,1,tanh,cone,adam')

# %%
# os.makedirs("Data Cone", exist_ok=True)

# loss_file = os.path.join("Data Cone", "loss_over_time_cone_adam.pth")

# torch.save(loss_over_time, loss_file)
# print(f"Loss saved to {loss_file}")

# %% [markdown]
# ### Visualize the result

# %%
# model.load_state_dict(torch.load('Trained Models/3,32,32,1,tanh,cone,gn'))

# %%
verts, faces = get_mesh(
    model.float(), N=128, device=device,
    bbox_min=torch.tensor([-1.2, -1.2, -0.05], dtype=torch.float64),
    bbox_max=torch.tensor([1.2, 1.2, 1.05], dtype=torch.float64),
    chunks=2
)


fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(verts, faces, color=0xbbbbbb, side='double', flat_shading=False)
fig += k3d.points(pts_boundary.cpu().detach(), color=0x00ff00, point_size=0.02)
fig.display()
# Out:
# Output()

# %%
verts, faces = get_mesh(
    model.float(), N=256, device=device,
    bbox_min=torch.tensor([-2, -2, -0.05], dtype=torch.float64),
    bbox_max=torch.tensor([2, 2, 1.05], dtype=torch.float64),
    chunks=2
)

model.double()
from torch.func import vmap

# Vectorized gauss curvature calculation
mean_curvatures = vmap(res_lib._gauss_curvature, in_dims=(None, 0))(
    model.params, torch.tensor(verts, dtype=torch.float64)
).squeeze()

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)

color_map = k3d.basic_color_maps.Jet
color_range = [0, 0.005]

fig += k3d.mesh(
    verts, faces, 
    attribute=mean_curvatures.cpu().detach().numpy().astype(np.float32),
    color_range=color_range,
    color_map=color_map,
    side='double',
    flat_shading=False
)

fig += k3d.points(pts_boundary.cpu().detach(), color=0x00ff00, point_size=0.05)

fig.display()
# Out:
# Output()

# %%
# fig_output_file = "../docs/k3d_plot_cone_gn.html"
# with open(fig_output_file, 'w') as f:
#     f.write(fig.get_snapshot())
# print(f"Plot saved to {fig_output_file}")
