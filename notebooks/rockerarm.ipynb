# %% [markdown]
# # Reconstruct Rocker Arm

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import optim
from tqdm.notebook import trange
import k3d
import sys
import os
import time
import copy
import trimesh
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
from models.model_architecture import GeneralNet
from training.optimizers import GaussNewton, GaussNewtonNew
from util.surface_sampling import sample_model_surface_binsearch, sample_model_surface_newton 
from util.error_metrics import chamfer_div, compute_distance 
from util.visualization.utils_mesh import get_mesh
from training.residuals import bind_model, r_data, r_eikonal, r_normal

torch.manual_seed(0)


device = 'cuda' #if torch.cuda.is_available() else 'cpu'
torch.set_default_device(device)

# %%
mesh = trimesh.load("rocker-arm.off")
fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(mesh.vertices, mesh.faces, color=0xbbbbbb, side='double', flat_shading=False)
# fig += k3d.points(pts_sub.cpu().detach(), color=0x00ff00, point_size=0.05)

fig.display()
# Out:
# /cluster/home/jaking/.local/lib/python3.11/site-packages/traittypes/traittypes.py:97: UserWarning: Given trait value dtype "float64" does not match required type "float32". A coerced copy has been created.
#   warnings.warn(
# /cluster/home/jaking/.local/lib/python3.11/site-packages/traittypes/traittypes.py:97: UserWarning: Given trait value dtype "int64" does not match required type "uint32". A coerced copy has been created.
#   warnings.warn(
# Output()

# %%
pts = torch.tensor(mesh.vertices, dtype=torch.float64)
true_normals = torch.tensor(mesh.vertex_normals, dtype=torch.float64)

center = pts.mean(dim=0)
pts -= center

scale = pts.norm(dim=1).max()
pts /= scale

# subsample_fraction = 0.2
# subsample_fraction = 0.3
subsample_fraction = 1.0
num_points = pts.shape[0]

# Randomly shuffle the points
indices = torch.randperm(num_points)
num_subsampled = int(subsample_fraction * num_points)
subsampled_indices = indices[:num_subsampled]
pts_sub = pts[subsampled_indices]
true_normals_sub = true_normals[subsampled_indices]

# %% [markdown]
# ## Pretraining

# %%
model = GeneralNet(ks=[3, 32, 32, 32, 1], act=torch.sin)
model = model.double()
torch.compile(model)
bind_model(model)

# Generate random training points
num_pretrain_samples = 10000
bounds = torch.tensor([[-1.5, 1.5], [-1.5, 1.5], [-1.5, 1.5]], dtype=torch.float64)
pts_pretrain = torch.rand(num_pretrain_samples, 3, dtype=torch.float64) * (bounds[:,1] - bounds[:,0]) + bounds[:,0]

# SDF of a unit ball
def pretrain_loss(model, params, pts):
    inputs = pts.to(dtype=torch.float64)
    targets = inputs.norm(dim=1) - 1  # SDF of unit ball
    preds = model(inputs).squeeze(1)
    return 0.5 * (preds - targets).square().mean()

# Pretraining loop
pretrain_optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
num_pretrain_iters = 1000

for i in range(num_pretrain_iters):
    pretrain_optimizer.zero_grad()
    loss = pretrain_loss(model, model.params, pts_pretrain)
    loss.backward()
    pretrain_optimizer.step()
    
    if i % 100 == 0:
        print(f"Pretrain Iter {i}: Loss = {loss.item():.6f}")

print("Pretraining completed!")
# Out:
# Pretrain Iter 0: Loss = 0.305483
# Pretrain Iter 100: Loss = 0.083794
# Pretrain Iter 200: Loss = 0.006071
# Pretrain Iter 300: Loss = 0.000854
# Pretrain Iter 400: Loss = 0.000712
# Pretrain Iter 500: Loss = 0.000620
# Pretrain Iter 600: Loss = 0.000546
# Pretrain Iter 700: Loss = 0.000486
# Pretrain Iter 800: Loss = 0.000435
# Pretrain Iter 900: Loss = 0.000394
# Pretraining completed!

# %%
verts, faces = get_mesh(
    model.float(), N=128, device=device,
    bbox_min=torch.tensor([-1, -1, -1], dtype=torch.float64),
    bbox_max=torch.tensor([1, 1, 1], dtype=torch.float64),
    chunks=2
)

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(verts, faces, color=0xbbbbbb, side='double', flat_shading=False)
fig += k3d.points(pts.cpu().detach(), color=0x00ff00, point_size=0.05)
fig.display()
model.double()
# Out:
# /cluster/home/jaking/.local/lib/python3.11/site-packages/traittypes/traittypes.py:97: UserWarning: Given trait value dtype "int32" does not match required type "uint32". A coerced copy has been created.
#   warnings.warn(
# Output()
# GeneralNet(
#   (fcs): ModuleList(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1-2): 2 x Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
# Gauss-Newton weights:
# loss_weights = {"interface": 1.0, "eikonal": 0.001, "normal": 1.0}
loss_weights = {"data": 1.0, "eikonal": 0.01, "normal": 1.0}
# loss_weights = {"interface": 1.0, "eikonal": 0.1, "normal": 1.0}


# loss_weights = {"interface": 1.0, "eikonal": 0.1, "mean_curvature": 0.0}


# pts_eikonal = 2 * torch.rand([1000, 3], dtype=torch.float64) - 1
min_vals = pts.min(dim=0).values-0.2  # min along each axis (x, y, z)
max_vals = pts.max(dim=0).values+0.2
# pts_eikonal = torch.rand([15000, 3], dtype=torch.float64)
pts_eikonal = torch.rand([7000, 3], dtype=torch.float64)
pts_eikonal = pts_eikonal * (max_vals - min_vals) + min_vals
# n_per_dim = int(round(4000 ** (1/3)))  # ~16 to get ~4096 points total

# x = torch.linspace(min_vals[0], max_vals[0], steps=n_per_dim, dtype=torch.float64)
# y = torch.linspace(min_vals[1], max_vals[1], steps=n_per_dim, dtype=torch.float64)
# z = torch.linspace(min_vals[2], max_vals[2], steps=n_per_dim, dtype=torch.float64)

# X, Y, Z = torch.meshgrid(x, y, z, indexing='ij')
# pts_eikonal = torch.stack([X, Y, Z], dim=-1).reshape(-1, 3)

# pts_surface = sample_model_surface_binsearch(model, torch.rand([0, 3], dtype=torch.float64), bound_limit=1)
# pts_surface = pts

config = {
    "pts_data": pts_sub,
    "pts_eikonal": pts_eikonal,
    "pts_surface": pts_sub,
    "true_normals": true_normals_sub,
    "loss_weights": loss_weights,
    "regularization": 1e-6,    
}

# model = PlaceholderNet(ks=[3, 32, 32, 32, 1], act=torch.sin)
# model.double()

# %%
model = model.double()
params = model.params
loss_over_iters = {}
loss_over_time = {}
distance_over_time = {}
chamfer_over_time = {}
best_loss = float('inf')

start_time = time.time()
current_time = 0

# Gauss-Newton:
optimizer = GaussNewtonNew(model, lr=1e-1, config=config)
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
for i in (pbar:=trange(10000)):
    if current_time > 600:
        break
    optimizer.zero_grad()
    with torch.no_grad():
        loss_data  = 0.5*r_data(params, pts_sub, torch.zeros(pts_sub.shape[0], dtype=torch.float64)).squeeze(1).square().mean()
        loss_eikonal  = 0.5*r_eikonal(params, pts_eikonal).squeeze(1).square().mean()
        loss_normal = 0.5*r_normal(params, pts_sub, true_normals_sub).squeeze(1).square().mean()
        # loss = loss_weights["data"] * loss_data + loss_weights["eikonal"] * loss_eikonal + loss_weights["normal"] * loss_normal
        # loss.backward()
        loss_metric = loss_data + loss_normal
        loss_over_time[current_time] = loss_metric.item()
        pbar.set_description(f"Interface: {loss_data.item():.2e} "
                             f"Eikonal: {loss_eikonal.item():.2e} "
                             f"Normal: {loss_normal.item():.2e} "
                             f"{len(pts_sub)}")
        if loss_metric.item() < best_loss:
            best_loss = loss_metric.item()
            best_model_state = copy.deepcopy(model.state_dict())
    optimizer.step()
    current_time = time.time() - start_time

plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 34
#      32             best_loss = loss_metric.item()
#      33             best_model_state = copy.deepcopy(model.state_dict())
# ---> 34     optimizer.step()
#      35     current_time = time.time() - start_time
#      37 plt.plot(loss_over_time.keys(), loss_over_time.values())
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Master Thesis/PreconditionGINNs/training/optimizers.py:172, in GaussNewtonNew.step(self)
#     169 self.t += 1
#     171 if not self.do_woodbury:
# --> 172     update = self.calculate_update()
#     173 else:
#     174     update = self.calculate_update_woodbury()
#
# File ~/Master Thesis/PreconditionGINNs/training/optimizers.py:154, in GaussNewtonNew.calculate_update(self)
#     152 def calculate_update(self):
#     153     r = compute_residual(self.model, self.config)
# --> 154     grad = compute_Jv(self.model, self.config, r)
#     155     eps = self.config.get("regularization", 0.0)
#     156     A = compute_JJT(self.params_dict, self.config) + eps * torch.eye(grad.shape[0], dtype=grad.dtype)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Master Thesis/PreconditionGINNs/training/gram_factory.py:630, in compute_Jv(model, config, v)
#     628     true_normals = config["true_normals"]
#     629     N = pts.shape[0]
# --> 630     grad = flatten_layer_grads(grad_theta_r_normal(layer_params, pts, true_normals), layer_name)
#     631     J_layer.append(np.sqrt(loss_weights["normal"] / N) * grad)
#     633 # Mean Curvature
#
# File ~/Master Thesis/PreconditionGINNs/training/residuals.py:89, in grad_theta_r_normal(params, x, true_normal)
#      88 def grad_theta_r_normal(params, x, true_normal):
# ---> 89     return vmap(_grad_theta_r_normal, in_dims=(None, 0, 0), out_dims=(0))(params, x, true_normal)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/apis.py:188, in vmap.<locals>.wrapped(*args, **kwargs)
#     187 def wrapped(*args, **kwargs):
# --> 188     return vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/vmap.py:281, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     277     return _chunked_vmap(func, flat_in_dims, chunks_flat_args,
#     278                          args_spec, out_dims, randomness, **kwargs)
#     280 # If chunk_size is not specified.
# --> 281 return _flat_vmap(
#     282     func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs
#     283 )
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/vmap.py:47, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      44 @functools.wraps(f)
#      45 def fn(*args, **kwargs):
#      46     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 47         return f(*args, **kwargs)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/vmap.py:403, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     401 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     402     batched_inputs = _create_batched_inputs(flat_in_dims, flat_args, vmap_level, args_spec)
# --> 403     batched_outputs = func(*batched_inputs, **kwargs)
#     404     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/Master Thesis/PreconditionGINNs/training/residuals.py:86, in _grad_theta_r_normal(params, x, true_normal)
#      85 def _grad_theta_r_normal(params, x, true_normal):
# ---> 86     return jacrev(_r_normal, argnums=0)(params, x, true_normal)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/eager_transforms.py:537, in jacrev.<locals>.wrapper_fn(*args)
#     533 error_if_complex("jacrev", flat_output, is_input=False)
#     535 # NB: vjp already checks that all outputs are tensors
#     536 # Step 1: Construct grad_outputs by splitting the standard basis
# --> 537 flat_output_numels = tuple(out.numel() for out in flat_output)
#     539 primals = _slice_argnums(args, argnums)
#     540 flat_primals, primals_spec = tree_flatten(primals)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/eager_transforms.py:537, in <genexpr>(.0)
#     533 error_if_complex("jacrev", flat_output, is_input=False)
#     535 # NB: vjp already checks that all outputs are tensors
#     536 # Step 1: Construct grad_outputs by splitting the standard basis
# --> 537 flat_output_numels = tuple(out.numel() for out in flat_output)
#     539 primals = _slice_argnums(args, argnums)
#     540 flat_primals, primals_spec = tree_flatten(primals)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/utils/_device.py:78, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#      76 if func in _device_constructors() and kwargs.get('device') is None:
#      77     kwargs['device'] = self.device
# ---> 78 return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
model = model.double()
params = model.params
loss_over_iters = {}
loss_over_time = {}
distance_over_time = {}
chamfer_over_time = {}
best_loss = float('inf')

start_time = time.time()
current_time = 0

# Gauss-Newton:
optimizer = GaussNewton(model, lr=1e-1, config=config, do_line_search=True)
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
for i in (pbar:=trange(10000)):
    if current_time > 600:
        break
    optimizer.zero_grad()
    loss_data  = 0.5*r_data(params, pts_sub, torch.zeros(pts_sub.shape[0], dtype=torch.float64)).squeeze(1).square().mean()
    loss_eikonal  = 0.5*r_eikonal(params, pts_eikonal).squeeze(1).square().mean()
    loss_normal = 0.5*r_normal(params, pts_sub, true_normals_sub).squeeze(1).square().mean()
    loss = loss_weights["data"] * loss_data + loss_weights["eikonal"] * loss_eikonal + loss_weights["normal"] * loss_normal
    loss.backward()
    with torch.no_grad():
        loss_metric = loss_data + loss_normal
        loss_over_time[current_time] = loss_metric.item()
        pbar.set_description(f"Interface: {loss_data.item():.2e} "
                             f"Eikonal: {loss_eikonal.item():.2e} "
                             f"Normal: {loss_normal.item():.2e} "
                             f"{len(pts_sub)}")
        if loss_metric.item() < best_loss:
            best_loss = loss_metric.item()
            best_model_state = copy.deepcopy(model.state_dict())
    optimizer.step()
    current_time = time.time() - start_time

plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 34
#      32             best_loss = loss_metric.item()
#      33             best_model_state = copy.deepcopy(model.state_dict())
# ---> 34     optimizer.step()
#      35     current_time = time.time() - start_time
#      37 plt.plot(loss_over_time.keys(), loss_over_time.values())
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Master Thesis/PreconditionGINNs/training/optimizers.py:54, in GaussNewton.step(self)
#      49 """
#      50 Perform a single Gauss-Newton update step on all parameters:
#      51 """
#      52 self.t += 1
# ---> 54 self.apply_preconditioner_to_grads()
#      56 # if not self.do_line_search:
#      57 #     for param in self.params_list:
#      58 #         if param.grad is None:
#    (...)
#      61 # If line search is enabled
#      62 # TODO: do line search like in GaussNewtonNew, seems to work better
#      63 if self.do_line_search:
#
# File ~/Master Thesis/PreconditionGINNs/training/optimizers.py:37, in GaussNewton.apply_preconditioner_to_grads(self)
#      35 N = flat_grads.numel()
#      36 eps = self.config.get("regularization")
# ---> 37 A = compute_JJT(self.params_dict, self.config) + eps*torch.eye(N)
#      39 # 2. Solve least squares: x = argmin_x ||A*x - grads||^2
#      40 x, _, _, _ = torch.linalg.lstsq(A.double(), flat_grads.double(), driver="gels")
#
# File ~/Master Thesis/PreconditionGINNs/training/gram_factory.py:26, in compute_JJT(params, config)
#      24 if loss_weights.get("eikonal", 0) != 0 and "pts_eikonal" in config:
#      25     pts = config["pts_eikonal"]
# ---> 26     JJT += loss_weights["eikonal"] * compute_JJT_per_residual(params, pts, grad_theta_r_eikonal)
#      28 if "pts_surface" in config:
#      29     pts = config["pts_surface"]
#
# File ~/Master Thesis/PreconditionGINNs/training/gram_factory.py:10, in compute_JJT_per_residual(params, pts, grad_theta_r, vals)
#       9 def compute_JJT_per_residual(params, pts, grad_theta_r, vals=None):
# ---> 10     J_dict = grad_theta_r(params, pts, vals)
#      11     J = torch.cat([p.flatten(start_dim=1) for p in J_dict.values()], dim=1)
#      12     JJT = torch.einsum('bi,bj->ij', J, J) / len(pts)
#
# File ~/Master Thesis/PreconditionGINNs/training/residuals.py:74, in grad_theta_r_eikonal(params, x, vals)
#      73 def grad_theta_r_eikonal(params, x, vals=None):
# ---> 74     return vmap(_grad_theta_r_eikonal, in_dims=(None, 0, None), out_dims=(0))(params, x, vals)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/apis.py:188, in vmap.<locals>.wrapped(*args, **kwargs)
#     187 def wrapped(*args, **kwargs):
# --> 188     return vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/vmap.py:281, in vmap_impl(func, in_dims, out_dims, randomness, chunk_size, *args, **kwargs)
#     277     return _chunked_vmap(func, flat_in_dims, chunks_flat_args,
#     278                          args_spec, out_dims, randomness, **kwargs)
#     280 # If chunk_size is not specified.
# --> 281 return _flat_vmap(
#     282     func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs
#     283 )
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/vmap.py:47, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      44 @functools.wraps(f)
#      45 def fn(*args, **kwargs):
#      46     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 47         return f(*args, **kwargs)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/vmap.py:403, in _flat_vmap(func, batch_size, flat_in_dims, flat_args, args_spec, out_dims, randomness, **kwargs)
#     401 with vmap_increment_nesting(batch_size, randomness) as vmap_level:
#     402     batched_inputs = _create_batched_inputs(flat_in_dims, flat_args, vmap_level, args_spec)
# --> 403     batched_outputs = func(*batched_inputs, **kwargs)
#     404     return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# File ~/Master Thesis/PreconditionGINNs/training/residuals.py:71, in _grad_theta_r_eikonal(params, x, vals)
#      70 def _grad_theta_r_eikonal(params, x, vals=None):
# ---> 71     return jacrev(_r_eikonal, argnums=0)(params, x, vals)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/eager_transforms.py:524, in jacrev.<locals>.wrapper_fn(*args)
#     521 @wraps(func)
#     522 def wrapper_fn(*args):
#     523     error_if_complex("jacrev", args, is_input=True)
# --> 524     vjp_out = _vjp_with_argnums(func, *args, argnums=argnums, has_aux=has_aux)
#     525     if has_aux:
#     526         output, vjp_fn, aux = vjp_out
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/vmap.py:47, in doesnt_support_saved_tensors_hooks.<locals>.fn(*args, **kwargs)
#      44 @functools.wraps(f)
#      45 def fn(*args, **kwargs):
#      46     with torch.autograd.graph.disable_saved_tensors_hooks(message):
# ---> 47         return f(*args, **kwargs)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/eager_transforms.py:334, in _vjp_with_argnums(func, argnums, has_aux, *primals)
#     332     diff_primals = _slice_argnums(primals, argnums, as_tuple=False)
#     333     tree_map_(partial(_create_differentiable, level=level), diff_primals)
# --> 334 primals_out = func(*primals)
#     336 if has_aux:
#     337     if not (isinstance(primals_out, tuple) and len(primals_out) == 2):
#
# File ~/Master Thesis/PreconditionGINNs/training/residuals.py:65, in _r_eikonal(params, x, vals)
#      64 def _r_eikonal(params, x, vals=None):
# ---> 65     return _grad_x_f(params, x).squeeze(1).square().sum(1).sqrt() - 1
#
# File ~/Master Thesis/PreconditionGINNs/training/residuals.py:36, in _grad_x_f(params, x)
#      35 def _grad_x_f(params, x):
# ---> 36     return jacrev(_f, argnums=1)(params, x)
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/eager_transforms.py:633, in jacrev.<locals>.wrapper_fn(*args)
#     631     flat_jacobians_per_input = compute_jacobian_preallocate_and_copy()
#     632 else:
# --> 633     flat_jacobians_per_input = compute_jacobian_stacked()
#     635 # Step 2: The returned jacobian is one big tensor per input. In this step,
#     636 # we split each Tensor by output.
#     637 flat_jacobians_per_input = [result.split(flat_output_numels, dim=0) for result in flat_jacobians_per_input]
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/eager_transforms.py:547, in jacrev.<locals>.wrapper_fn.<locals>.compute_jacobian_stacked()
#     542 def compute_jacobian_stacked():
#     543     # Helper function to compute chunked Jacobian
#     544     # The intermediate chunked calculation are only
#     545     # scoped at this function level.
#     546     chunked_results = []
# --> 547     for flat_basis_chunk in _chunked_standard_basis_for_(flat_output,
#     548                                                          flat_output_numels,
#     549                                                          chunk_size=chunk_size):
#     550         if chunk_size == 1:
#     551             # sanity check.
#     552             for t in flat_basis_chunk:
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/_functorch/eager_transforms.py:738, in _chunked_standard_basis_for_(tensors, tensor_numels, chunk_size)
#     735     chunk_size = total_numel
#     736     chunk_numels = [total_numel]
# --> 738 diag_start_indices = (0, *torch.tensor(tensor_numels).cumsum(dim=0)[:-1].neg().unbind())
#     740 for chunk_idx, total_numel in enumerate(chunk_numels):
#     741     chunks = tuple(tensor.new_zeros(total_numel, tensor_numel)
#     742                    for tensor, tensor_numel in zip(tensors, tensor_numels))
#
# File /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/torch/utils/_device.py:78, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#      76 if func in _device_constructors() and kwargs.get('device') is None:
#      77     kwargs['device'] = self.device
# ---> 78 return func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()

# %%
model = model.double()
params = model.params
loss_over_iters = {}
loss_over_time = {}
distance_over_time = {}
chamfer_over_time = {}
best_loss = float('inf')

start_time = time.time()
current_time = 0
loss_weights = {"interface": 1.0, "eikonal": 0.1, "normal": 1.0}
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=28000)

for i in (pbar:=trange(100000)):
    if current_time > 600:
        break
    optimizer.zero_grad()
    loss_interface  = 0.5*model.f(params, pts_sub).square().mean()
    loss_eikonal  = 0.5*model.r_eikonal(params, pts_eikonal).squeeze(1).square().mean()
    loss_normal = 0.5*model.r_normal(params, pts_sub, true_normals_sub).squeeze(1).square().mean()
    loss = loss_weights["interface"] * loss_interface + loss_weights["eikonal"] * loss_eikonal + loss_weights["normal"] * loss_normal
    loss.backward()
    with torch.no_grad():
        loss_metric = loss_interface + loss_normal
        loss_over_time[current_time] = loss_metric.item()
        pbar.set_description(f"Interface: {loss_interface.item():.2e} "
                             f"Eikonal: {loss_eikonal.item():.2e} "
                             f"Normal: {loss_normal.item():.2e} "
                             f"{len(pts_sub)}")
        if loss_metric.item() < best_loss:
            best_loss = loss_metric.item()
            best_model_state = copy.deepcopy(model.state_dict())
    optimizer.step()
    current_time = time.time() - start_time

plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()

# %%
model = model.double()
params = model.params
loss_over_iters = {}
loss_over_time = {}
distance_over_time = {}
chamfer_over_time = {}
best_loss = float('inf')

start_time = time.time()
current_time = 0
loss_weights = {"interface": 1.0, "eikonal": 0.1, "normal": 1.0}
optimizer = torch.optim.LBFGS(model.parameters(), line_search_fn="strong_wolfe")

def closure():
    optimizer.zero_grad()
    loss_interface = 0.5 * model.f(params, pts_sub).square().mean()
    loss_eikonal = 0.5 * model.r_eikonal(params, pts_eikonal).squeeze(1).square().mean()
    loss_normal = 0.5 * model.r_normal(params, pts_sub, true_normals_sub).squeeze(1).square().mean()
    loss = (loss_weights["interface"] * loss_interface +
            loss_weights["eikonal"] * loss_eikonal +
            loss_weights["normal"] * loss_normal)
    loss.backward()
    return loss

for i in (pbar := trange(10000)):
    if current_time > 600:
        break
    with torch.no_grad():
        loss_interface = 0.5 * model.f(params, pts_sub).square().mean()
        loss_eikonal = 0.5 * model.r_eikonal(params, pts_eikonal).squeeze(1).square().mean()
        loss_normal = 0.5 * model.r_normal(params, pts_sub, true_normals_sub).squeeze(1).square().mean()
        loss_metric = loss_interface + loss_normal
        loss_over_time[current_time] = loss_metric.item()
        pbar.set_description(f"Interface: {loss_interface.item():.2e} "
                             f"Eikonal: {loss_eikonal.item():.2e} "
                             f"Normal: {loss_normal.item():.2e} "
                             f"{len(pts_sub)}")
        if loss_metric.item() < best_loss:
            best_loss = loss_metric.item()
            best_model_state = copy.deepcopy(model.state_dict())

    optimizer.step(closure)
    current_time = time.time() - start_time

plt.plot(loss_over_time.keys(), loss_over_time.values())
plt.semilogy()
plt.show()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
verts, faces = get_mesh(
    model.float(), N=128, device=device,
    bbox_min=pts.min(dim=0).values-0.01,
    bbox_max=pts.max(dim=0).values+0.15,
    chunks=2
)

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(verts, faces, color=0xbbbbbb, side='double', flat_shading=False)
# fig += k3d.points(pts_surface.cpu().detach(), color=0x00ff00, point_size=0.05)
fig.display()
model.double()
# Out:
# Output()
# GeneralNet(
#   (fcs): ModuleList(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1-2): 2 x Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
verts, faces = get_mesh(
    model.float(), N=128, device=device,
    bbox_min=pts.min(dim=0).values-0.01,
    bbox_max=pts.max(dim=0).values+0.15,
    chunks=2
)

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(verts, faces, color=0xbbbbbb, side='double', flat_shading=False)
# fig += k3d.points(pts_surface.cpu().detach(), color=0x00ff00, point_size=0.05)
fig.display()
model.double()
# Out:
# Output()
# GeneralNet(
#   (fcs): ModuleList(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1-2): 2 x Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
verts, faces = get_mesh(
    model.float(), N=128, device=device,
    bbox_min=pts.min(dim=0).values-0.01,
    bbox_max=pts.max(dim=0).values+0.15,
    chunks=2
)

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(verts, faces, color=0xbbbbbb, side='double', flat_shading=False)
# fig += k3d.points(pts_surface.cpu().detach(), color=0x00ff00, point_size=0.05)
fig.display()
model.double()
# Out:
# Output()
# GeneralNet(
#   (fcs): ModuleList(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1-2): 2 x Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
os.makedirs("Data Rocker Arm", exist_ok=True)

loss_file = os.path.join("Data Rocker Arm", "loss_over_time_rockerarm_gn.pth")

torch.save(loss_over_time, loss_file)
print(f"Loss saved to {loss_file}")
# Out:
# Loss saved to Data Rocker Arm/loss_over_time_rockerarm_gn.pth

# %%
torch.save(model.state_dict(), '3,32,32,32,1,sin,rockerarm,lbfgs')

# %%
verts, faces = get_mesh(
    model.float(), N=128, device=device,
    bbox_min=pts.min(dim=0).values-0.01,
    bbox_max=pts.max(dim=0).values+0.15,
    chunks=2
)

fig = k3d.plot(height=800, grid_visible=False, camera_fov=1.0)
fig += k3d.mesh(verts, faces, color=0xbbbbbb, side='double', flat_shading=False)
# fig += k3d.points(pts_surface.cpu().detach(), color=0x00ff00, point_size=0.05)
fig.display()
model.double()
# Out:
# Output()
# PlaceholderNet(
#   (fcs): ModuleList(
#     (0): Linear(in_features=3, out_features=32, bias=True)
#     (1-2): 2 x Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
torch.save(model.state_dict(), '3,32,32,32,1,sin,rockerarm,adam')
